# %%
import pandas as pd

df = pd.read_csv('8d76ac6b-5ae8-4428-82a4-043130d17b02.csv')
col = next((c for c in df.columns if c.lower() == 'neighborhood'), None)
counts = df[col].value_counts()

print("Incident counts by neighborhood:")
for name, count in counts.items():
    print(f"{name}: {count}")

least = counts.sort_values().head(10)

print("\nTop 10 neighborhoods with the fewest incidents:")
for i, (name, count) in enumerate(least.items(), 1):
    print(f"{i}. {name} - {count} incidents")
# Out:
# Incident counts by neighborhood:
# Carrick: 328
# South Side Flats: 307
# Central Business District: 304
# Squirrel Hill South: 281
# Hazelwood: 264
# Mount Washington: 238
# East Liberty: 230
# Brookline: 209
# Homewood South: 209
# Lincoln-Lemington-Belmar: 206
# Knoxville: 205
# Shadyside: 201
# Homewood North: 197
# Bloomfield: 191
# Sheraden: 181
# Perry South: 174
# East Hills: 166
# Beechview: 163
# Brighton Heights: 163
# Marshall-Shadeland: 162
# Bluff: 159
# Squirrel Hill North: 142
# East Allegheny: 142
# Beltzhoover: 141
# Central Northside: 139
# North Oakland: 136
# Allentown: 136
# Larimer: 130
# Greenfield: 129
# Garfield: 121
# Spring Hill-City View: 119
# Crawford-Roberts: 117
# Perry North: 117
# South Side Slopes: 115
# Middle Hill: 110
# South Oakland: 104
# Central Oakland: 104
# North Shore: 91
# Troy Hill: 89
# Crafton Heights: 89
# Terrace Village: 88
# Highland Park: 86
# Manchester: 84
# Central Lawrenceville: 80
# Strip District: 80
# Point Breeze: 78
# ...

# %% [markdown]
# Conclusion for notebook:
# According do the data the safest neighborhood is squirrel hill north, which is also my favourite neighborhood. As a Pittsburgh native i have seen many of pittsburghs neighborhoods and i have always felt the safest in squirrel hill, and it makes sense as it boasts one of the most educated populations in the city as it has CMU and Chatham university, and it is filled with lush vegitation, clean parks and clean, sidewalks making it
